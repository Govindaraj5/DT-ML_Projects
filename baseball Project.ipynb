# %%
import pandas as pd
import numpy as np

# %%
# read the data from Gitup
basball_df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')

# %%
basball_df.shape
# Out:
# (30, 17)

# %%
# check the df
basball_df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# #   Problem Definition
#
#     This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# W – Win: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work (also related: winning percentage)
#
# R – Runs scored: times reached home plate legally and safely
#
# AB – At bat: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction
#
# H – Hit: reaching base because of a batted, fair ball without error by the defense
#
# 2B – Double: hits on which the batter reaches second base safely without the contribution of a fielding error
#
# 3B – Triple: hits on which the batter reaches third base safely without the contribution of a fielding error
#
# HR – Home runs: hits on which the batter successfully touched all four bases, without the contribution of a fielding error
#
# BB – Base on balls (also called a "walk"): hitter not swinging at four pitches called out of the strike zone and awarded first base.
#
# K (or SO) – Strikeout: number of batters who received strike three
#
# RA – Run average: number of runs allowed times nine divided by innings pitched
#
# ER – Earned run: number of runs that did not occur as a result of errors or passed balls
#
# ERA – Earned run average: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched
#
# CG – Complete game: number of games where player was the only pitcher for their team
#
# SHO – Shutout: number of complete games pitched with no runs allowed
#
# SV – Save: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings
#
# E – Errors: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result

# %%
# check in the null values in df and there is no null values in df we can proceed furthur.
basball_df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
# check data type of coloumns
basball_df.dtypes
# all the col are numeric col hence there is no need of changing data types
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# looking at the there is no big sweness presents in the data however there are few coloumns max and 75% perc

# %% [markdown]
# EDA, here i will do univariate analysis and bi variate anaylis

# %%
# to perform EDA i will be using charts and graphs so I am downloading the required packages for that 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # since the data is numeric i will do bivariate analysis like IV vs DV

# %%
#R – Runs scored: times reached home plate legally and safely

sns.scatterplot(x=basball_df['R'],y=basball_df['W'])
plt.xlabel('Runs')
plt.ylabel('wins')
plt.title('Runs vs Wins')
plt.show()

# %% [markdown]
# obaserved:  graph explains that as run increases the winnings increases and its possitive correlation. as graph represents,close to 775 runs covered my 80% of the data.

# %%
#AB – At bat: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction
sns.scatterplot(x=basball_df['AB'],y=basball_df['W'])
plt.xlabel('at bat')
plt.ylabel('wins')
plt.title('At bat vs Wins')
plt.show()

# %% [markdown]
# obaserved: there is no specific indicator because the data is spread across and looking from domain perspective different player has the different approach in batting and lets from correlation metric in down to see the correlation

# %%
#H – Hit: reaching base because of a batted, fair ball without error by the defense
sns.scatterplot(x=basball_df['H'],y=basball_df['W'])
plt.xlabel('Hit')
plt.ylabel('wins')
plt.title('Hit vs Wins')
plt.show()

# %% [markdown]
# obaserved: data is spread across and no specific findings and lets see the correlation metric down

# %%
#2B – Double: hits on which the batter reaches second base safely without the contribution of a fielding error
sns.scatterplot(x=basball_df['2B'],y=basball_df['W'])
plt.xlabel('Doubles')
plt.ylabel('wins')
plt.title('Doubles vs Wins')
plt.show()

# %% [markdown]
# obaserved: its has the possitive relation, as doubles increases the chances of winning increases although its not highly correlated each other.

# %%
#3B – Triple: hits on which the batter reaches third base safely without the contribution of a fielding error
sns.scatterplot(x=basball_df['3B'],y=basball_df['W'])
plt.xlabel('Triples')
plt.ylabel('wins')
plt.title('Triples vs Wins')
plt.show()

# %%
#HR – Home runs: hits on which the batter successfully touched all four bases, without the contribution of a fielding error
sns.scatterplot(x=basball_df['HR'],y=basball_df['W'])
plt.xlabel('HomeRuns')
plt.ylabel('wins')
plt.title('HomeRuns vs Wins')
plt.show()

# %%
#BB – Base on balls (also called a "walk"): hitter not swinging at four pitches called out of the strike zone 
#and awarded first base.
sns.scatterplot(x=basball_df['BB'],y=basball_df['W'])
plt.xlabel('BaseBalls')
plt.ylabel('wins')
plt.title('BaseBalls vs Wins')
plt.show()

# %%
#SO – Strikeout: number of batters who received strike three
sns.scatterplot(x=basball_df['SO'],y=basball_df['W'])
plt.xlabel('Strikeout')
plt.ylabel('wins')
plt.title('Strikeout vs Wins')
plt.show()

# %%
#RA – Run average: number of runs allowed times nine divided by innings pitched
sns.scatterplot(x=basball_df['RA'],y=basball_df['W'])
plt.xlabel('Run average')
plt.ylabel('wins')
plt.title('Run average vs Wins')
plt.show()

# %% [markdown]
# obaserved: its a negative correlation

# %%
#ER – Earned run: number of runs that did not occur as a result of errors or passed balls
sns.scatterplot(x=basball_df['ER'],y=basball_df['W'])
plt.xlabel('Earned run')
plt.ylabel('wins')
plt.title('Earned run vs Wins')
plt.show()

# %% [markdown]
# obaserved: as plot shows when result of error increases the winning decreases , its highly negative corelated.

# %%
#ERA – Earned run average: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched
sns.scatterplot(x=basball_df['ERA'],y=basball_df['W'])
plt.xlabel('Earned run average')
plt.ylabel('wins')
plt.title('Earned run average vs Wins')
plt.show()

# %%
#CG – Complete game: number of games where player was the only pitcher for their team(A pitcher earns a complete game if he pitches the entire game for his team regardless of how long it lasts)
sns.scatterplot(x=basball_df['CG'],y=basball_df['W'])
plt.xlabel('Complete game')
plt.ylabel('Wins')
plt.title('Complete game vs Wins')
plt.show()

# %% [markdown]
# observed:if a pitcher has the less complete game which means that particular pitcher has pitched whole game in less matches and high credit

# %%
#SHO – Shutout: number of complete games pitched with no runs allowed(a shutout when the pitcher pitches the entire game for a team and does not allow the opposition to score)
sns.scatterplot(x=basball_df['SHO'],y=basball_df['W'])
plt.xlabel('Shutout')
plt.ylabel('wins')
plt.title('Shutout vs Wins')
plt.show()

# %%
#SV – Save: number of games where the pitcher enters a game led by the pitcher's team, 
    #finishes the game without surrendering the lead, is not the winning pitcher, and either
    #(a) the lead was three runs or fewer when the pitcher entered the game; 
    #(b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings
sns.scatterplot(x=basball_df['SV'],y=basball_df['W'])
plt.xlabel('Save')
plt.ylabel('wins')
plt.title('Save vs Wins')
plt.show()

# %% [markdown]
# Obaserved : More saves by a pitcher leads to good wins

# %%
#E – Errors: number of times a fielder fails to make a play he should have made with common effort,
#and the offense benefits as a result

sns.scatterplot(x=basball_df['E'],y=basball_df['W'])
plt.xlabel('Errors')
plt.ylabel('wins')
plt.title('Errors vs Wins')
plt.show()

# %% [markdown]
# Obaserved : less error will have the high wins.plot shows that arroung 60-70% of the <100 errors

# %%
# describe the df
plt.figure(figsize=(18,5))
sns.heatmap(basball_df.describe(),annot=True,linewidths=0.2,linecolor='white',fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Findings: when we see the 75% and max we dont find a big difference in order to make a callout of Skweness.however still there are coloums which has the little skewne. Col: SO,HR,SB, CG,SHO and E. Lets see below how much they skewed after checking the correaltion.

# %%
# find the correlation over the target variable
basball_df.corr()['W'].sort_values(ascending=True)
# Out:
# ERA   -0.819600
# RA    -0.812952
# ER    -0.809435
# 3B    -0.251118
# SB    -0.157234
# E     -0.089485
# AB    -0.087947
# H      0.037612
# CG     0.080533
# SO     0.111850
# HR     0.307407
# 2B     0.427797
# R      0.430751
# SHO    0.471805
# BB     0.484342
# SV     0.666530
# W      1.000000
# Name: W, dtype: float64

# %% [markdown]
# Findings: we see ERA,RA,ER,3B,SB,E and AB is in negative correlation which tells us that when these coloumns increases then the the winning reducess because of the negative correlation.

# %%
# heatmap on correlation
plt.figure(figsize=(15,5))
sns.heatmap(basball_df.corr(),annot=True,linecolor='White',linewidths=0.1,fmt='0.2f')
# Out:
# <AxesSubplot:>

# %%
# plotting another IV over DV w.r.t the correaltion to which variables goes possitive correlation and negative correlation 
plt.figure(figsize=(15,5))
basball_df.corr()['W'].sort_values(ascending=False).drop(['W']).plot(kind='bar',color='green')
plt.xlabel('Independant variable',fontsize=14)
plt.ylabel('Dependant variable',fontsize=14)
plt.title('Correlation IV vs DV')
plt.show()

# %%
# find the skewness of the variable
from scipy.stats import skew
basball_df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
# plot of swkness for all the variable to understand the which variable is swkeved
for col in basball_df:
    print(col)
    print(skew(basball_df[col]))
    
    plt.figure()
    sns.distplot(basball_df[col])
    plt.show()
# Out:
# W
# 0.04470076997798572
# R
# 1.1398931660307043
# AB
# 0.17413429032352498
# H
# 0.6362644174348592
# 2B
# -0.2189534077067715
# 3B
# 0.12293523975827839
# HR
# 0.49025146140832154
# BB
# 0.15046085271433388
# SO
# -0.14815122992357777
# SB
# 0.4555569751737513
# RA
# 0.04341475534967941
# ER
# 0.055732557686200515
# ERA
# 0.0506268488741678
# CG
# 0.6994790420153237
# SHO
# 0.5370985776239573
# SV
# 0.6241798071870271
# E
# 0.8449922672006391

# %%
# import power_transform method to treat the skwness
#from sklearn.preprocessing import power_transform
#x_new=power_transform(x)
#x=pd.DataFrame(x_new,columns=x.columns)
# Out:
# C:\Users\Hp\AppData\Roaming\Python\Python39\site-packages\sklearn\preprocessing\_data.py:3253: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())

# %%
# check outlier using box plot
basball_df.boxplot(figsize=(15,10))
plt.show()

# %% [markdown]
# there are oultlier in the col of SHO and E from  the box plot and to handle the outliers we use zscore

# %%
# when i tried with z>3 i get empty list which means there is outlier technically.i did cross
# whether the code was ran correct or it was a code issue hence i used z>2 then i found few of values which means there is no outlier hence I am going furthur
#np.where(z>2)
# Out:
# (array([ 0,  2,  5,  5,  8, 11, 14, 15, 15, 15, 15, 16, 17, 17, 19, 22, 23,
#         25, 27, 29, 29, 29], dtype=int64),
#  array([ 8, 13,  1,  6, 15,  6, 16, 10, 11, 12, 15, 16,  8, 14,  9,  4,  6,
#         14,  9, 10, 11, 12], dtype=int64))

# %%
X=basball_df.drop(['W'],axis=1)
X.shape
# Out:
# (30, 16)

# %%
Y=basball_df['W']
Y.shape
# Out:
# (30,)

# %%
# importing required packages to run the model, since the target is a contineous variable we will be builing Linear regression model
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,200):
    X_train,X_test,Y_train,Y_test=train_test_split(X,Y,random_state=i,test_size=0.25)
    lr.fit(X_train,Y_train)
    pred_train=lr.predict(X_train)
    pred_test=lr.predict(X_test)
    print(f"At random state{i},the training accuracy is:{r2_score(y_train,pred_train)}")
    print(f"At random state{i},the test accuracy is:{r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# At random state0,the training accuracy is:-2.2417803674538166
# At random state0,the test accuracy is:-0.44512204376715325
#
#
# At random state1,the training accuracy is:-0.6277229511496651
# At random state1,the test accuracy is:-1.3400734443860163
#
#
# At random state2,the training accuracy is:-0.672820271815443
# At random state2,the test accuracy is:-0.47611591276841003
#
#
# At random state3,the training accuracy is:-1.7347958050858008
# At random state3,the test accuracy is:-2.1762207983568653
#
#
# At random state4,the training accuracy is:-1.252731066072979
# At random state4,the test accuracy is:-0.6586313679543978
#
#
# At random state5,the training accuracy is:-0.5327038981391528
# At random state5,the test accuracy is:-0.2798482553528956
#
#
# At random state6,the training accuracy is:-1.327855455354591
# At random state6,the test accuracy is:-0.5998278293736121
#
#
# At random state7,the training accuracy is:-0.5768645414396412
# ...

# %%
pre_train
# Out:
# array([86.3694145 , 87.84317842, 86.72233815, 69.85971652, 77.50232992,
#        66.68438461, 98.34469304, 73.72697864, 78.94167905, 64.25233401,
#        83.075022  , 91.94673415, 72.86510031, 92.32741654, 81.658189  ,
#        69.25673052, 65.2146423 , 81.8258205 , 84.82787302, 85.85849981,
#        77.47996286, 95.41696213])

# %%
# Random state 99 has the acc
#the training accuracy is:0.9571383242408464
#At random state99,the test accuracy is:0.7257065088780261


# splitting the data using random state 99

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,random_state=99,test_size=0.25)

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(X_test)

# %%
print(f"At random state{i},the test accuracy is:{r2_score(y_test,pred_test)}")
# Out:
# At random state199,the test accuracy is:0.7257065088780261

# %% [markdown]
# # Cross validation of the model

# %%
train_Accuracy=r2_score(y_train,pred_train)
test_accuracy=r2_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score

for k in range(2,10):
    cv_score=cross_val_score(lr,X,Y,cv=k)
    cv_mean=cv_score.mean()
    print(f"At cross validation {k} the cv score is {cv_mean} and accuracy score for training is {train_Accuracy} and acc for test is {test_accuracy}")
    print('\n')
# Out:
# At cross validation 2 the cv score is -1.057932205834568 and accuracy score for training is -1.410129292096808 and acc for test is 0.7257065088780261
#
#
# At cross validation 3 the cv score is 0.2258846016774 and accuracy score for training is -1.410129292096808 and acc for test is 0.7257065088780261
#
#
# At cross validation 4 the cv score is 0.24952166654368527 and accuracy score for training is -1.410129292096808 and acc for test is 0.7257065088780261
#
#
# At cross validation 5 the cv score is 0.04075540667465847 and accuracy score for training is -1.410129292096808 and acc for test is 0.7257065088780261
#
#
# At cross validation 6 the cv score is 0.2515353093720216 and accuracy score for training is -1.410129292096808 and acc for test is 0.7257065088780261
#
#
# At cross validation 7 the cv score is 0.3890804644289939 and accuracy score for training is -1.410129292096808 and acc for test is 0.7257065088780261
#
#
# ...

# %%
# plot the final data
from matplotlib import pyplot as plt
plt.figure(figsize=(15,4))
plt.scatter(x=Y_test,y=pred_test,color='blue')
plt.plot(Y_test,Y_test,color='red')
plt.show()

# %% [markdown]
# # Regularisation

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
import warnings 
warnings.filterwarnings('ignore')

# %%
from sklearn.linear_model import Lasso

parameters = {'alpha':[.0001, .001, .01, .1, 1, 10],'random_state':list(range(0,10))}
ls = Lasso()
clf = GridSearchCV(ls,parameters)
clf.fit(X_train,Y_train)

print(clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
# final model building 
ls=Lasso(alpha=10,random_state=1)
ls.fit(X_train,Y_train)
ls_score_training=ls.score(X_train,Y_train)
pred_ls=ls.predict(X_test)
ls_score_training*100
# Out:
# 86.81704276225274

# %%
lss=r2_score(Y_test,pred_ls)
lss*100
# Out:
# 84.87180543020611

# %%
# final predicted values
from matplotlib import pyplot as plt
plt.figure(figsize=(15,4))
plt.scatter(x=Y_test,y=pred_ls,color='blue')
plt.plot(Y_test,Y_test,color='red')
plt.show()

# %% [markdown]
#  model is providing 84 as a model accurancy which is pretty good hence I will save that model

# %%
# save the model using pickle
import pickle
file_name="baseballwin.pkl"
pickle.dump(ls,open(file_name,'wb'))

# %%
loaded_model=pickle.load(open('baseballwin.pkl','rb'))
result=loaded_model.score(X_test,Y_test)
result*100
# Out:
# 84.87180543020611

# %%
#create a df Actual vs predicted value 
import pandas as pd
Output_df=pd.DataFrame([loaded_model.predict(X_test)[:],Y_test[:]],index=["Predicted","Actual"])
Output_df
# Out:
#                    0          1          2          3          4          5  \
# Predicted  63.466424  61.649026  95.179132  78.238743  88.450339  81.074647
# Actual     67.000000  63.000000  98.000000  85.000000  83.000000  79.000000
#
#                    6           7
# Predicted  79.076879   98.525876
# Actual     88.000000  100.000000
